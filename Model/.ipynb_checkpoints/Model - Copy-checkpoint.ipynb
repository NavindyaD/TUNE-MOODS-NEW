# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Activation, Input
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
import os
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from tensorflow.keras.regularizers import l2 # For L2 regularization

# %%
# --- 1. Define Dataset Paths and Parameters ---
# Ensure these paths are correct for your system
train_dir = 'D:/Faces/train'
validation_dir = 'D:/Faces/validation'
img_size = (48, 48) # Standard for FER datasets, adjust if your images are larger/smaller
batch_size = 64
num_classes = 7 # angry, disgust, fear, happy, neutral, sad, surprise

# Create a directory for saving logs and plots
# Changed directory name to avoid overwriting previous runs and to ensure a fresh start
# If you encounter the OSError again, try changing 'model_output_v3' to something new like 'model_output_v4'
output_dir = 'model_output_v3'
os.makedirs(output_dir, exist_ok=True)

# %%
# --- 2. Data Loading and Preprocessing with Even More Aggressive Augmentation & Techniques ---
# Key for hitting higher accuracy: Robust Data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255, # Normalize pixel values
    rotation_range=25, # Increased rotation
    width_shift_range=0.18, # Increased shift
    height_shift_range=0.18, # Increased shift
    shear_range=0.18, # Increased shear
    zoom_range=0.18, # Increased zoom
    horizontal_flip=True,
    fill_mode='nearest',
    brightness_range=[0.7, 1.3], # Added brightness augmentation
    channel_shift_range=50, # Added channel shift (adjust for grayscale, might need testing)
    # Consider adding Random Erasing/Cutout for further robustness
    # This requires custom implementation or using external libraries like Albumentations
    # For now, we'll stick to Keras's built-in options.
)

validation_datagen = ImageDataGenerator(rescale=1./255) # Only rescale for validation

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    color_mode='grayscale', # Assuming grayscale images
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=img_size,
    color_mode='grayscale', # Assuming grayscale images
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False # Keep order for evaluation
)
# Out:
# Found 24155 images belonging to 7 classes.
# Found 6460 images belonging to 7 classes.

# %%
# --- 3. Model Architecture (Depper, Wider CNN with L2 Regularization) ---
# Aiming for a VGG-like structure with Batch Normalization and Dropout
# L2 regularization helps prevent overfitting by penalizing large weights
def build_advanced_cnn(input_shape, num_classes, l2_reg=0.0001):
    model = Sequential([
        # Block 1
        Conv2D(64, (3, 3), padding='same', kernel_regularizer=l2(l2_reg), input_shape=input_shape),
        BatchNormalization(),
        Activation('relu'),
        Conv2D(64, (3, 3), padding='same', kernel_regularizer=l2(l2_reg)),
        BatchNormalization(),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.35), # Slightly increased dropout

        # Block 2
        Conv2D(128, (3, 3), padding='same', kernel_regularizer=l2(l2_reg)),
        BatchNormalization(),
        Activation('relu'),
        Conv2D(128, (3, 3), padding='same', kernel_regularizer=l2(l2_reg)),
        BatchNormalization(),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.35),

        # Block 3
        Conv2D(256, (3, 3), padding='same', kernel_regularizer=l2(l2_reg)),
        BatchNormalization(),
        Activation('relu'),
        Conv2D(256, (3, 3), padding='same', kernel_regularizer=l2(l2_reg)),
        BatchNormalization(),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.4), # Increased dropout

        # Block 4 (More capacity for complex features)
        Conv2D(512, (3, 3), padding='same', kernel_regularizer=l2(l2_reg)),
        BatchNormalization(),
        Activation('relu'),
        Conv2D(512, (3, 3), padding='same', kernel_regularizer=l2(l2_reg)),
        BatchNormalization(),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.4),

        Flatten(),
        Dense(512, kernel_regularizer=l2(l2_reg)),
        BatchNormalization(),
        Activation('relu'),
        Dropout(0.5), # Standard dropout for dense layers

        Dense(num_classes, activation='softmax')
    ])
    return model

model = build_advanced_cnn(input_shape=(img_size[0], img_size[1], 1), num_classes=num_classes, l2_reg=0.0001)
# Out:
# C:\Users\Navindya\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# --- 4. Compile the Model ---
# Very crucial: Optimal Learning Rate and Optimizer
# Using a slightly lower initial learning rate and more aggressive LR reduction might help.
# Also, consider a "warm-up" phase for the learning rate, but that's more advanced.
optimizer = Adam(learning_rate=0.0005) # Experiment with 0.001, 0.0005, 0.0001
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 48, 48, 64)          │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 48, 48, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 48, 48, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 48, 48, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 48, 48, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 48, 48, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 24, 24, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 24, 24, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 24, 24, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 24, 24, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 24, 24, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 24, 24, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 12, 12, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 12, 12, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 12, 12, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 12, 12, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_4 (Activation)            │ (None, 12, 12, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 12, 12, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 12, 12, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_5 (Activation)            │ (None, 12, 12, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 6, 6, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 6, 6, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 6, 6, 512)           │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 6, 6, 512)           │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_6 (Activation)            │ (None, 6, 6, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 6, 6, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 6, 6, 512)           │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_7 (Activation)            │ (None, 6, 6, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 3, 3, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 3, 3, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 4608)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_8                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_8 (Activation)            │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 7)                   │           3,591 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,057,351 (26.92 MB)
#  Trainable params: 7,052,487 (26.90 MB)
#  Non-trainable params: 4,864 (19.00 KB)

# %%
# --- 5. Callbacks for Training (Fine-tuned for better convergence and avoiding overfitting) ---
# IMPORTANT: Changed the model saving format to .keras (native Keras format)
# This is the recommended format and can sometimes avoid HDF5-related locking issues.
checkpoint_filepath = os.path.join(output_dir, 'best_model_over_70.keras')
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False, # Save the entire model
    monitor='val_accuracy',
    mode='max',
    save_best_only=True,
    verbose=1
)

early_stopping_callback = EarlyStopping(
    monitor='val_accuracy',
    patience=30, # Increased patience further to allow more time for LR reduction and convergence
    mode='max',
    restore_best_weights=True,
    verbose=1
)

reduce_lr_callback = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=12, # Increased patience for LR reduction
    min_lr=0.0000001, # Even smaller min_lr
    mode='min',
    verbose=1
)

csv_logger_callback = CSVLogger(os.path.join(output_dir, 'training_log.csv'), append=True)

callbacks_list = [model_checkpoint_callback, early_stopping_callback, reduce_lr_callback, csv_logger_callback]

# %%
# --- 6. Train the Model ---
epochs = 200 # Increased epochs, EarlyStopping will handle stopping

history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    callbacks=callbacks_list
)
# Out:
# C:\Users\Navindya\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2164 - loss: 2.4141
# Epoch 1: val_accuracy improved from -inf to 0.25969, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 921s 2s/step - accuracy: 0.2164 - loss: 2.4138 - val_accuracy: 0.2597 - val_loss: 2.0658 - learning_rate: 5.0000e-04
# Epoch 2/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 11:09 2s/step - accuracy: 0.2500 - loss: 2.2716
# C:\Users\Navindya\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 2: val_accuracy did not improve from 0.25969
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 52s 134ms/step - accuracy: 0.2500 - loss: 2.2716 - val_accuracy: 0.2592 - val_loss: 2.0645 - learning_rate: 5.0000e-04
# Epoch 3/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2507 - loss: 2.1783
# Epoch 3: val_accuracy did not improve from 0.25969
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 876s 2s/step - accuracy: 0.2507 - loss: 2.1783 - val_accuracy: 0.2023 - val_loss: 2.1816 - learning_rate: 5.0000e-04
# Epoch 4/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 11:08 2s/step - accuracy: 0.3125 - loss: 2.0035
# Epoch 4: val_accuracy did not improve from 0.25969
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 53s 135ms/step - accuracy: 0.3125 - loss: 2.0035 - val_accuracy: 0.2130 - val_loss: 2.1719 - learning_rate: 5.0000e-04
# Epoch 5/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2830 - loss: 2.0969
# Epoch 5: val_accuracy improved from 0.25969 to 0.35375, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 848s 2s/step - accuracy: 0.2831 - loss: 2.0968 - val_accuracy: 0.3537 - val_loss: 1.8835 - learning_rate: 5.0000e-04
# Epoch 6/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 11:12 2s/step - accuracy: 0.2656 - loss: 2.0286
# Epoch 6: val_accuracy improved from 0.35375 to 0.36016, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 54s 139ms/step - accuracy: 0.2656 - loss: 2.0286 - val_accuracy: 0.3602 - val_loss: 1.8714 - learning_rate: 5.0000e-04
# Epoch 7/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3526 - loss: 1.9419
# Epoch 7: val_accuracy did not improve from 0.36016
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 738s 2s/step - accuracy: 0.3527 - loss: 1.9418 - val_accuracy: 0.2738 - val_loss: 2.5853 - learning_rate: 5.0000e-04
# Epoch 8/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 11:08 2s/step - accuracy: 0.4688 - loss: 1.7814
# Epoch 8: val_accuracy did not improve from 0.36016
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 53s 136ms/step - accuracy: 0.4688 - loss: 1.7814 - val_accuracy: 0.2738 - val_loss: 2.6157 - learning_rate: 5.0000e-04
# Epoch 9/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4146 - loss: 1.7684
# Epoch 9: val_accuracy improved from 0.36016 to 0.40531, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 730s 2s/step - accuracy: 0.4147 - loss: 1.7683 - val_accuracy: 0.4053 - val_loss: 1.9575 - learning_rate: 5.0000e-04
# Epoch 10/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 11:20 2s/step - accuracy: 0.5469 - loss: 1.5175
# Epoch 10: val_accuracy did not improve from 0.40531
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 53s 137ms/step - accuracy: 0.5469 - loss: 1.5175 - val_accuracy: 0.3980 - val_loss: 2.0243 - learning_rate: 5.0000e-04
# Epoch 11/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4727 - loss: 1.6339
# Epoch 11: val_accuracy improved from 0.40531 to 0.52438, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 732s 2s/step - accuracy: 0.4727 - loss: 1.6338 - val_accuracy: 0.5244 - val_loss: 1.5113 - learning_rate: 5.0000e-04
# Epoch 12/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 11:05 2s/step - accuracy: 0.5156 - loss: 1.5650
# Epoch 12: val_accuracy improved from 0.52438 to 0.52594, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 50s 128ms/step - accuracy: 0.5156 - loss: 1.5650 - val_accuracy: 0.5259 - val_loss: 1.5077 - learning_rate: 5.0000e-04
# Epoch 13/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 863ms/step - accuracy: 0.5106 - loss: 1.5406
# Epoch 13: val_accuracy did not improve from 0.52594
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 348s 923ms/step - accuracy: 0.5106 - loss: 1.5405 - val_accuracy: 0.5245 - val_loss: 1.5007 - learning_rate: 5.0000e-04
# Epoch 14/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 5:52 937ms/step - accuracy: 0.3906 - loss: 1.8441
# Epoch 14: val_accuracy did not improve from 0.52594
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.3906 - loss: 1.8441 - val_accuracy: 0.5230 - val_loss: 1.5023 - learning_rate: 5.0000e-04
# Epoch 15/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 881ms/step - accuracy: 0.5303 - loss: 1.4775
# Epoch 15: val_accuracy did not improve from 0.52594
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 358s 950ms/step - accuracy: 0.5303 - loss: 1.4774 - val_accuracy: 0.5183 - val_loss: 1.5470 - learning_rate: 5.0000e-04
# Epoch 16/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 5:50 932ms/step - accuracy: 0.4219 - loss: 1.6500
# Epoch 16: val_accuracy improved from 0.52594 to 0.52797, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - accuracy: 0.4219 - loss: 1.6500 - val_accuracy: 0.5280 - val_loss: 1.5122 - learning_rate: 5.0000e-04
# Epoch 17/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5522 - loss: 1.4281
# Epoch 17: val_accuracy improved from 0.52797 to 0.54719, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 427s 1s/step - accuracy: 0.5522 - loss: 1.4281 - val_accuracy: 0.5472 - val_loss: 1.4609 - learning_rate: 5.0000e-04
# Epoch 18/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 7:05 1s/step - accuracy: 0.5156 - loss: 1.4179
# Epoch 18: val_accuracy improved from 0.54719 to 0.55375, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 31s 79ms/step - accuracy: 0.5156 - loss: 1.4179 - val_accuracy: 0.5537 - val_loss: 1.4287 - learning_rate: 5.0000e-04
# Epoch 19/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5689 - loss: 1.3873
# Epoch 19: val_accuracy did not improve from 0.55375
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 463s 1s/step - accuracy: 0.5689 - loss: 1.3873 - val_accuracy: 0.4606 - val_loss: 1.6832 - learning_rate: 5.0000e-04
# Epoch 20/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 6:18 1s/step - accuracy: 0.5469 - loss: 1.4659
# Epoch 20: val_accuracy did not improve from 0.55375
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 30s 77ms/step - accuracy: 0.5469 - loss: 1.4659 - val_accuracy: 0.4764 - val_loss: 1.6395 - learning_rate: 5.0000e-04
# Epoch 21/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5784 - loss: 1.3522
# Epoch 21: val_accuracy did not improve from 0.55375
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 553s 1s/step - accuracy: 0.5784 - loss: 1.3522 - val_accuracy: 0.5484 - val_loss: 1.4554 - learning_rate: 5.0000e-04
# Epoch 22/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 5:33 886ms/step - accuracy: 0.6250 - loss: 1.3244
# Epoch 22: val_accuracy did not improve from 0.55375
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 33s 86ms/step - accuracy: 0.6250 - loss: 1.3244 - val_accuracy: 0.5492 - val_loss: 1.4564 - learning_rate: 5.0000e-04
# Epoch 23/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5775 - loss: 1.3444
# Epoch 23: val_accuracy improved from 0.55375 to 0.56422, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 551s 1s/step - accuracy: 0.5775 - loss: 1.3444 - val_accuracy: 0.5642 - val_loss: 1.4673 - learning_rate: 5.0000e-04
# Epoch 24/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 5:56 947ms/step - accuracy: 0.5938 - loss: 1.1841
# Epoch 24: val_accuracy improved from 0.56422 to 0.56937, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 33s 86ms/step - accuracy: 0.5938 - loss: 1.1841 - val_accuracy: 0.5694 - val_loss: 1.4616 - learning_rate: 5.0000e-04
# Epoch 25/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5963 - loss: 1.3129
# Epoch 25: val_accuracy did not improve from 0.56937
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 553s 1s/step - accuracy: 0.5962 - loss: 1.3129 - val_accuracy: 0.5469 - val_loss: 1.4531 - learning_rate: 5.0000e-04
# Epoch 26/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 5:11 828ms/step - accuracy: 0.6406 - loss: 1.3926
# Epoch 26: val_accuracy did not improve from 0.56937
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 30s 76ms/step - accuracy: 0.6406 - loss: 1.3926 - val_accuracy: 0.5519 - val_loss: 1.4224 - learning_rate: 5.0000e-04
# Epoch 27/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5948 - loss: 1.3159
# Epoch 27: val_accuracy improved from 0.56937 to 0.59891, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 502s 1s/step - accuracy: 0.5948 - loss: 1.3159 - val_accuracy: 0.5989 - val_loss: 1.3257 - learning_rate: 5.0000e-04
# Epoch 28/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 5:49 930ms/step - accuracy: 0.6719 - loss: 1.2282
# Epoch 28: val_accuracy improved from 0.59891 to 0.60078, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 35s 90ms/step - accuracy: 0.6719 - loss: 1.2282 - val_accuracy: 0.6008 - val_loss: 1.3269 - learning_rate: 5.0000e-04
# Epoch 29/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6031 - loss: 1.2969
# Epoch 29: val_accuracy did not improve from 0.60078
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 582s 2s/step - accuracy: 0.6031 - loss: 1.2969 - val_accuracy: 0.5758 - val_loss: 1.3884 - learning_rate: 5.0000e-04
# Epoch 30/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 7:53 1s/step - accuracy: 0.5312 - loss: 1.4284
# Epoch 30: val_accuracy did not improve from 0.60078
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 33s 84ms/step - accuracy: 0.5312 - loss: 1.4284 - val_accuracy: 0.5708 - val_loss: 1.4033 - learning_rate: 5.0000e-04
# Epoch 31/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6041 - loss: 1.2880
# Epoch 31: val_accuracy did not improve from 0.60078
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 550s 1s/step - accuracy: 0.6041 - loss: 1.2880 - val_accuracy: 0.5931 - val_loss: 1.3093 - learning_rate: 5.0000e-04
# Epoch 32/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 9:19 1s/step - accuracy: 0.6250 - loss: 1.2572
# Epoch 32: val_accuracy did not improve from 0.60078
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 39s 99ms/step - accuracy: 0.6250 - loss: 1.2572 - val_accuracy: 0.5905 - val_loss: 1.3143 - learning_rate: 5.0000e-04
# Epoch 33/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6028 - loss: 1.2884
# Epoch 33: val_accuracy did not improve from 0.60078
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 503s 1s/step - accuracy: 0.6028 - loss: 1.2884 - val_accuracy: 0.5958 - val_loss: 1.3337 - learning_rate: 5.0000e-04
# Epoch 34/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 5:20 851ms/step - accuracy: 0.5625 - loss: 1.5003
# Epoch 34: val_accuracy did not improve from 0.60078
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 30s 76ms/step - accuracy: 0.5625 - loss: 1.5003 - val_accuracy: 0.5933 - val_loss: 1.3449 - learning_rate: 5.0000e-04
# Epoch 35/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6104 - loss: 1.2755
# Epoch 35: val_accuracy did not improve from 0.60078
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 524s 1s/step - accuracy: 0.6104 - loss: 1.2755 - val_accuracy: 0.5944 - val_loss: 1.3188 - learning_rate: 5.0000e-04
# Epoch 36/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 7:35 1s/step - accuracy: 0.5938 - loss: 1.4009
# Epoch 36: val_accuracy did not improve from 0.60078
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 86s 226ms/step - accuracy: 0.5938 - loss: 1.4009 - val_accuracy: 0.5877 - val_loss: 1.3305 - learning_rate: 5.0000e-04
# Epoch 37/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6059 - loss: 1.2862
# Epoch 37: val_accuracy improved from 0.60078 to 0.60547, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 701s 2s/step - accuracy: 0.6059 - loss: 1.2861 - val_accuracy: 0.6055 - val_loss: 1.3603 - learning_rate: 5.0000e-04
# Epoch 38/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 11:32 2s/step - accuracy: 0.6094 - loss: 1.2677
# Epoch 38: val_accuracy did not improve from 0.60547
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 39s 99ms/step - accuracy: 0.6094 - loss: 1.2677 - val_accuracy: 0.6048 - val_loss: 1.3639 - learning_rate: 5.0000e-04
# Epoch 39/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6179 - loss: 1.2612
# Epoch 39: val_accuracy did not improve from 0.60547
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 605s 2s/step - accuracy: 0.6179 - loss: 1.2612 - val_accuracy: 0.5883 - val_loss: 1.3327 - learning_rate: 5.0000e-04
# Epoch 40/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 9:18 1s/step - accuracy: 0.5781 - loss: 1.3173
# Epoch 40: val_accuracy did not improve from 0.60547
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.5781 - loss: 1.3173 - val_accuracy: 0.5889 - val_loss: 1.3402 - learning_rate: 5.0000e-04
# Epoch 41/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6213 - loss: 1.2561
# Epoch 41: val_accuracy did not improve from 0.60547
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 585s 2s/step - accuracy: 0.6213 - loss: 1.2562 - val_accuracy: 0.6009 - val_loss: 1.3528 - learning_rate: 5.0000e-04
# Epoch 42/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 9:49 2s/step - accuracy: 0.6250 - loss: 1.1730
# Epoch 42: val_accuracy did not improve from 0.60547
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 39s 99ms/step - accuracy: 0.6250 - loss: 1.1730 - val_accuracy: 0.5995 - val_loss: 1.3616 - learning_rate: 5.0000e-04
# Epoch 43/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6261 - loss: 1.2470
# Epoch 43: val_accuracy did not improve from 0.60547
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 768s 2s/step - accuracy: 0.6261 - loss: 1.2470 - val_accuracy: 0.6011 - val_loss: 1.3453 - learning_rate: 5.0000e-04
# Epoch 44/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 12:04 2s/step - accuracy: 0.7031 - loss: 1.0547
# Epoch 44: val_accuracy did not improve from 0.60547
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 52s 132ms/step - accuracy: 0.7031 - loss: 1.0547 - val_accuracy: 0.6017 - val_loss: 1.3447 - learning_rate: 1.0000e-04
# Epoch 45/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6484 - loss: 1.1980
# Epoch 45: val_accuracy improved from 0.60547 to 0.64156, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 763s 2s/step - accuracy: 0.6484 - loss: 1.1980 - val_accuracy: 0.6416 - val_loss: 1.1973 - learning_rate: 1.0000e-04
# Epoch 46/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 12:00 2s/step - accuracy: 0.7031 - loss: 1.0056
# Epoch 46: val_accuracy did not improve from 0.64156
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 55s 142ms/step - accuracy: 0.7031 - loss: 1.0056 - val_accuracy: 0.6416 - val_loss: 1.1966 - learning_rate: 1.0000e-04
# Epoch 47/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6527 - loss: 1.1741
# Epoch 47: val_accuracy improved from 0.64156 to 0.64750, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 762s 2s/step - accuracy: 0.6527 - loss: 1.1741 - val_accuracy: 0.6475 - val_loss: 1.1902 - learning_rate: 1.0000e-04
# Epoch 48/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 11:22 2s/step - accuracy: 0.6094 - loss: 1.1457
# Epoch 48: val_accuracy did not improve from 0.64750
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 55s 140ms/step - accuracy: 0.6094 - loss: 1.1457 - val_accuracy: 0.6472 - val_loss: 1.1894 - learning_rate: 1.0000e-04
# Epoch 49/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6518 - loss: 1.1501
# Epoch 49: val_accuracy did not improve from 0.64750
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 761s 2s/step - accuracy: 0.6518 - loss: 1.1501 - val_accuracy: 0.6422 - val_loss: 1.1805 - learning_rate: 1.0000e-04
# Epoch 50/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 11:33 2s/step - accuracy: 0.5938 - loss: 1.4544
# Epoch 50: val_accuracy did not improve from 0.64750
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 55s 142ms/step - accuracy: 0.5938 - loss: 1.4544 - val_accuracy: 0.6422 - val_loss: 1.1794 - learning_rate: 1.0000e-04
# Epoch 51/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6647 - loss: 1.1179
# Epoch 51: val_accuracy improved from 0.64750 to 0.64797, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 498s 1s/step - accuracy: 0.6647 - loss: 1.1179 - val_accuracy: 0.6480 - val_loss: 1.1781 - learning_rate: 1.0000e-04
# Epoch 52/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 7:02 1s/step - accuracy: 0.7031 - loss: 0.9830
# Epoch 52: val_accuracy did not improve from 0.64797
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - accuracy: 0.7031 - loss: 0.9830 - val_accuracy: 0.6473 - val_loss: 1.1782 - learning_rate: 1.0000e-04
# Epoch 53/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6604 - loss: 1.1165
# Epoch 53: val_accuracy improved from 0.64797 to 0.65469, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 423s 1s/step - accuracy: 0.6604 - loss: 1.1164 - val_accuracy: 0.6547 - val_loss: 1.1390 - learning_rate: 1.0000e-04
# Epoch 54/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 6:05 973ms/step - accuracy: 0.7031 - loss: 1.0623
# Epoch 54: val_accuracy improved from 0.65469 to 0.65516, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 40s 103ms/step - accuracy: 0.7031 - loss: 1.0623 - val_accuracy: 0.6552 - val_loss: 1.1389 - learning_rate: 1.0000e-04
# Epoch 55/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6622 - loss: 1.1067
# Epoch 55: val_accuracy did not improve from 0.65516
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 596s 2s/step - accuracy: 0.6622 - loss: 1.1067 - val_accuracy: 0.6459 - val_loss: 1.1930 - learning_rate: 1.0000e-04
# Epoch 56/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 7:34 1s/step - accuracy: 0.7188 - loss: 1.0724
# Epoch 56: val_accuracy did not improve from 0.65516
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 40s 103ms/step - accuracy: 0.7188 - loss: 1.0724 - val_accuracy: 0.6452 - val_loss: 1.1912 - learning_rate: 1.0000e-04
# Epoch 57/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6683 - loss: 1.0849
# Epoch 57: val_accuracy did not improve from 0.65516
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 575s 2s/step - accuracy: 0.6683 - loss: 1.0849 - val_accuracy: 0.6453 - val_loss: 1.1649 - learning_rate: 1.0000e-04
# Epoch 58/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 5:55 945ms/step - accuracy: 0.6875 - loss: 1.1045
# Epoch 58: val_accuracy did not improve from 0.65516
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 34s 89ms/step - accuracy: 0.6875 - loss: 1.1045 - val_accuracy: 0.6473 - val_loss: 1.1626 - learning_rate: 1.0000e-04
# Epoch 59/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6718 - loss: 1.0740
# Epoch 59: val_accuracy improved from 0.65516 to 0.65625, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 504s 1s/step - accuracy: 0.6718 - loss: 1.0740 - val_accuracy: 0.6562 - val_loss: 1.1360 - learning_rate: 1.0000e-04
# Epoch 60/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 6:29 1s/step - accuracy: 0.7500 - loss: 1.0560
# Epoch 60: val_accuracy improved from 0.65625 to 0.65641, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.7500 - loss: 1.0560 - val_accuracy: 0.6564 - val_loss: 1.1364 - learning_rate: 1.0000e-04
# Epoch 61/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6702 - loss: 1.0825
# Epoch 61: val_accuracy did not improve from 0.65641
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 601s 2s/step - accuracy: 0.6702 - loss: 1.0824 - val_accuracy: 0.6533 - val_loss: 1.1235 - learning_rate: 1.0000e-04
# Epoch 62/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 8:10 1s/step - accuracy: 0.5938 - loss: 1.1955
# Epoch 62: val_accuracy did not improve from 0.65641
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 35s 90ms/step - accuracy: 0.5938 - loss: 1.1955 - val_accuracy: 0.6534 - val_loss: 1.1234 - learning_rate: 1.0000e-04
# Epoch 63/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6720 - loss: 1.0613
# Epoch 63: val_accuracy did not improve from 0.65641
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 623s 2s/step - accuracy: 0.6720 - loss: 1.0613 - val_accuracy: 0.6538 - val_loss: 1.1511 - learning_rate: 1.0000e-04
# Epoch 64/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 8:21 1s/step - accuracy: 0.6562 - loss: 1.0266
# Epoch 64: val_accuracy did not improve from 0.65641
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 37s 94ms/step - accuracy: 0.6562 - loss: 1.0266 - val_accuracy: 0.6517 - val_loss: 1.1503 - learning_rate: 1.0000e-04
# Epoch 65/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6702 - loss: 1.0690
# Epoch 65: val_accuracy did not improve from 0.65641
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 558s 1s/step - accuracy: 0.6702 - loss: 1.0690 - val_accuracy: 0.6562 - val_loss: 1.1451 - learning_rate: 1.0000e-04
# Epoch 66/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 6:08 981ms/step - accuracy: 0.5938 - loss: 1.3272
# Epoch 66: val_accuracy improved from 0.65641 to 0.65781, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - accuracy: 0.5938 - loss: 1.3272 - val_accuracy: 0.6578 - val_loss: 1.1427 - learning_rate: 1.0000e-04
# Epoch 67/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6690 - loss: 1.0470
# Epoch 67: val_accuracy did not improve from 0.65781
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 626s 2s/step - accuracy: 0.6690 - loss: 1.0470 - val_accuracy: 0.6533 - val_loss: 1.1423 - learning_rate: 1.0000e-04
# Epoch 68/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 11:31 2s/step - accuracy: 0.6250 - loss: 1.2325
# Epoch 68: val_accuracy did not improve from 0.65781
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 52s 135ms/step - accuracy: 0.6250 - loss: 1.2325 - val_accuracy: 0.6538 - val_loss: 1.1412 - learning_rate: 1.0000e-04
# Epoch 69/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6774 - loss: 1.0400
# Epoch 69: val_accuracy improved from 0.65781 to 0.66109, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 748s 2s/step - accuracy: 0.6774 - loss: 1.0400 - val_accuracy: 0.6611 - val_loss: 1.1184 - learning_rate: 1.0000e-04
# Epoch 70/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 11:01 2s/step - accuracy: 0.6094 - loss: 1.1941
# Epoch 70: val_accuracy did not improve from 0.66109
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 54s 138ms/step - accuracy: 0.6094 - loss: 1.1941 - val_accuracy: 0.6595 - val_loss: 1.1205 - learning_rate: 1.0000e-04
# Epoch 71/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6780 - loss: 1.0452
# Epoch 71: val_accuracy improved from 0.66109 to 0.66172, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 781s 2s/step - accuracy: 0.6780 - loss: 1.0452 - val_accuracy: 0.6617 - val_loss: 1.0944 - learning_rate: 1.0000e-04
# Epoch 72/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 12:08 2s/step - accuracy: 0.7500 - loss: 0.8952
# Epoch 72: val_accuracy improved from 0.66172 to 0.66266, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 56s 143ms/step - accuracy: 0.7500 - loss: 0.8952 - val_accuracy: 0.6627 - val_loss: 1.0947 - learning_rate: 1.0000e-04
# Epoch 73/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6809 - loss: 1.0324
# Epoch 73: val_accuracy did not improve from 0.66266
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 738s 2s/step - accuracy: 0.6809 - loss: 1.0324 - val_accuracy: 0.6561 - val_loss: 1.1141 - learning_rate: 1.0000e-04
# Epoch 74/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 11:45 2s/step - accuracy: 0.7031 - loss: 1.0323
# Epoch 74: val_accuracy did not improve from 0.66266
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 55s 141ms/step - accuracy: 0.7031 - loss: 1.0323 - val_accuracy: 0.6558 - val_loss: 1.1143 - learning_rate: 1.0000e-04
# Epoch 75/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6796 - loss: 1.0317
# Epoch 75: val_accuracy did not improve from 0.66266
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 838s 2s/step - accuracy: 0.6796 - loss: 1.0317 - val_accuracy: 0.6569 - val_loss: 1.1122 - learning_rate: 1.0000e-04
# Epoch 76/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 11:49 2s/step - accuracy: 0.6250 - loss: 1.1293
# Epoch 76: val_accuracy did not improve from 0.66266
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 56s 143ms/step - accuracy: 0.6250 - loss: 1.1293 - val_accuracy: 0.6567 - val_loss: 1.1123 - learning_rate: 1.0000e-04
# Epoch 77/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6803 - loss: 1.0329
# Epoch 77: val_accuracy did not improve from 0.66266
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 474s 1s/step - accuracy: 0.6803 - loss: 1.0328 - val_accuracy: 0.6623 - val_loss: 1.0954 - learning_rate: 1.0000e-04
# Epoch 78/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 6:40 1s/step - accuracy: 0.5938 - loss: 1.1263
# Epoch 78: val_accuracy did not improve from 0.66266
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 30s 77ms/step - accuracy: 0.5938 - loss: 1.1263 - val_accuracy: 0.6611 - val_loss: 1.0931 - learning_rate: 1.0000e-04
# Epoch 79/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6798 - loss: 1.0204
# Epoch 79: val_accuracy did not improve from 0.66266
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 424s 1s/step - accuracy: 0.6798 - loss: 1.0204 - val_accuracy: 0.6533 - val_loss: 1.1431 - learning_rate: 1.0000e-04
# Epoch 80/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 6:19 1s/step - accuracy: 0.6875 - loss: 0.9869
# Epoch 80: val_accuracy did not improve from 0.66266
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - accuracy: 0.6875 - loss: 0.9869 - val_accuracy: 0.6538 - val_loss: 1.1428 - learning_rate: 1.0000e-04
# Epoch 81/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6787 - loss: 1.0161
# Epoch 81: val_accuracy did not improve from 0.66266
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 422s 1s/step - accuracy: 0.6787 - loss: 1.0161 - val_accuracy: 0.6594 - val_loss: 1.1180 - learning_rate: 1.0000e-04
# Epoch 82/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 6:30 1s/step - accuracy: 0.7969 - loss: 0.9255
# Epoch 82: val_accuracy did not improve from 0.66266
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 31s 79ms/step - accuracy: 0.7969 - loss: 0.9255 - val_accuracy: 0.6592 - val_loss: 1.1158 - learning_rate: 1.0000e-04
# Epoch 83/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6861 - loss: 1.0065
# Epoch 83: val_accuracy did not improve from 0.66266
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 446s 1s/step - accuracy: 0.6861 - loss: 1.0065 - val_accuracy: 0.6597 - val_loss: 1.1207 - learning_rate: 1.0000e-04
# Epoch 84/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 8:42 1s/step - accuracy: 0.5625 - loss: 1.2146
# Epoch 84: val_accuracy did not improve from 0.66266
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 41s 104ms/step - accuracy: 0.5625 - loss: 1.2146 - val_accuracy: 0.6602 - val_loss: 1.1185 - learning_rate: 1.0000e-04
# Epoch 85/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6852 - loss: 1.0019
# Epoch 85: val_accuracy improved from 0.66266 to 0.66641, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 524s 1s/step - accuracy: 0.6852 - loss: 1.0018 - val_accuracy: 0.6664 - val_loss: 1.0944 - learning_rate: 1.0000e-04
# Epoch 86/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 6:05 973ms/step - accuracy: 0.7344 - loss: 0.8352
# Epoch 86: val_accuracy did not improve from 0.66641
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 36s 94ms/step - accuracy: 0.7344 - loss: 0.8352 - val_accuracy: 0.6648 - val_loss: 1.0939 - learning_rate: 1.0000e-04
# Epoch 87/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6891 - loss: 1.0056
# Epoch 87: val_accuracy improved from 0.66641 to 0.66922, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 560s 1s/step - accuracy: 0.6891 - loss: 1.0055 - val_accuracy: 0.6692 - val_loss: 1.1088 - learning_rate: 1.0000e-04
# Epoch 88/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 6:29 1s/step - accuracy: 0.7500 - loss: 0.8971
# Epoch 88: val_accuracy improved from 0.66922 to 0.66938, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 33s 85ms/step - accuracy: 0.7500 - loss: 0.8971 - val_accuracy: 0.6694 - val_loss: 1.1099 - learning_rate: 1.0000e-04
# Epoch 89/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6883 - loss: 0.9830
# Epoch 89: val_accuracy did not improve from 0.66938
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 457s 1s/step - accuracy: 0.6883 - loss: 0.9830 - val_accuracy: 0.6523 - val_loss: 1.1313 - learning_rate: 1.0000e-04
# Epoch 90/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 6:42 1s/step - accuracy: 0.6094 - loss: 1.2161
# Epoch 90: val_accuracy did not improve from 0.66938
#
# Epoch 90: ReduceLROnPlateau reducing learning rate to 2.0000000949949027e-05.
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 30s 76ms/step - accuracy: 0.6094 - loss: 1.2161 - val_accuracy: 0.6519 - val_loss: 1.1303 - learning_rate: 1.0000e-04
# Epoch 91/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6956 - loss: 0.9815
# Epoch 91: val_accuracy improved from 0.66938 to 0.67062, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 610s 2s/step - accuracy: 0.6956 - loss: 0.9814 - val_accuracy: 0.6706 - val_loss: 1.0814 - learning_rate: 2.0000e-05
# Epoch 92/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 5:35 893ms/step - accuracy: 0.7188 - loss: 0.8823
# Epoch 92: val_accuracy improved from 0.67062 to 0.67078, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 36s 93ms/step - accuracy: 0.7188 - loss: 0.8823 - val_accuracy: 0.6708 - val_loss: 1.0817 - learning_rate: 2.0000e-05
# Epoch 93/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6968 - loss: 0.9734
# Epoch 93: val_accuracy did not improve from 0.67078
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 600s 2s/step - accuracy: 0.6968 - loss: 0.9734 - val_accuracy: 0.6642 - val_loss: 1.0960 - learning_rate: 2.0000e-05
# Epoch 94/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 8:21 1s/step - accuracy: 0.7969 - loss: 0.6799
# Epoch 94: val_accuracy did not improve from 0.67078
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 35s 89ms/step - accuracy: 0.7969 - loss: 0.6799 - val_accuracy: 0.6636 - val_loss: 1.0963 - learning_rate: 2.0000e-05
# Epoch 95/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7052 - loss: 0.9567
# Epoch 95: val_accuracy did not improve from 0.67078
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 569s 2s/step - accuracy: 0.7052 - loss: 0.9567 - val_accuracy: 0.6697 - val_loss: 1.0816 - learning_rate: 2.0000e-05
# Epoch 96/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 7:12 1s/step - accuracy: 0.8750 - loss: 0.7640
# Epoch 96: val_accuracy did not improve from 0.67078
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 37s 94ms/step - accuracy: 0.8750 - loss: 0.7640 - val_accuracy: 0.6698 - val_loss: 1.0813 - learning_rate: 2.0000e-05
# Epoch 97/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6979 - loss: 0.9631
# Epoch 97: val_accuracy did not improve from 0.67078
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 495s 1s/step - accuracy: 0.6979 - loss: 0.9631 - val_accuracy: 0.6697 - val_loss: 1.0892 - learning_rate: 2.0000e-05
# Epoch 98/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 7:11 1s/step - accuracy: 0.6875 - loss: 1.0835
# Epoch 98: val_accuracy did not improve from 0.67078
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.6875 - loss: 1.0835 - val_accuracy: 0.6698 - val_loss: 1.0885 - learning_rate: 2.0000e-05
# Epoch 99/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7005 - loss: 0.9607
# Epoch 99: val_accuracy did not improve from 0.67078
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 426s 1s/step - accuracy: 0.7005 - loss: 0.9607 - val_accuracy: 0.6705 - val_loss: 1.0756 - learning_rate: 2.0000e-05
# Epoch 100/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 6:45 1s/step - accuracy: 0.7344 - loss: 0.9266
# Epoch 100: val_accuracy did not improve from 0.67078
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.7344 - loss: 0.9266 - val_accuracy: 0.6706 - val_loss: 1.0756 - learning_rate: 2.0000e-05
# Epoch 101/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7064 - loss: 0.9502
# Epoch 101: val_accuracy improved from 0.67078 to 0.67406, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 426s 1s/step - accuracy: 0.7064 - loss: 0.9502 - val_accuracy: 0.6741 - val_loss: 1.0764 - learning_rate: 2.0000e-05
# Epoch 102/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 5:57 950ms/step - accuracy: 0.6562 - loss: 0.9522
# Epoch 102: val_accuracy did not improve from 0.67406
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 30s 77ms/step - accuracy: 0.6562 - loss: 0.9522 - val_accuracy: 0.6741 - val_loss: 1.0765 - learning_rate: 2.0000e-05
# Epoch 103/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6939 - loss: 0.9630
# Epoch 103: val_accuracy did not improve from 0.67406
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 693s 2s/step - accuracy: 0.6939 - loss: 0.9630 - val_accuracy: 0.6712 - val_loss: 1.0886 - learning_rate: 2.0000e-05
# Epoch 104/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 12:13 2s/step - accuracy: 0.5938 - loss: 1.2368
# Epoch 104: val_accuracy did not improve from 0.67406
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 55s 141ms/step - accuracy: 0.5938 - loss: 1.2368 - val_accuracy: 0.6716 - val_loss: 1.0880 - learning_rate: 2.0000e-05
# Epoch 105/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7097 - loss: 0.9411
# Epoch 105: val_accuracy did not improve from 0.67406
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 764s 2s/step - accuracy: 0.7097 - loss: 0.9411 - val_accuracy: 0.6666 - val_loss: 1.0904 - learning_rate: 2.0000e-05
# Epoch 106/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 11:56 2s/step - accuracy: 0.6406 - loss: 0.9985
# Epoch 106: val_accuracy did not improve from 0.67406
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 55s 141ms/step - accuracy: 0.6406 - loss: 0.9985 - val_accuracy: 0.6670 - val_loss: 1.0907 - learning_rate: 2.0000e-05
# Epoch 107/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7070 - loss: 0.9409
# Epoch 107: val_accuracy did not improve from 0.67406
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 766s 2s/step - accuracy: 0.7070 - loss: 0.9409 - val_accuracy: 0.6670 - val_loss: 1.0950 - learning_rate: 2.0000e-05
# Epoch 108/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 11:57 2s/step - accuracy: 0.6719 - loss: 0.9197
# Epoch 108: val_accuracy did not improve from 0.67406
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 55s 141ms/step - accuracy: 0.6719 - loss: 0.9197 - val_accuracy: 0.6672 - val_loss: 1.0951 - learning_rate: 2.0000e-05
# Epoch 109/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7053 - loss: 0.9447
# Epoch 109: val_accuracy did not improve from 0.67406
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 767s 2s/step - accuracy: 0.7053 - loss: 0.9447 - val_accuracy: 0.6691 - val_loss: 1.0795 - learning_rate: 2.0000e-05
# Epoch 110/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 11:22 2s/step - accuracy: 0.6875 - loss: 0.9352
# Epoch 110: val_accuracy did not improve from 0.67406
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.6875 - loss: 0.9352 - val_accuracy: 0.6689 - val_loss: 1.0795 - learning_rate: 2.0000e-05
# Epoch 111/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7076 - loss: 0.9439
# Epoch 111: val_accuracy did not improve from 0.67406
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 427s 1s/step - accuracy: 0.7076 - loss: 0.9439 - val_accuracy: 0.6730 - val_loss: 1.0716 - learning_rate: 2.0000e-05
# Epoch 112/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 6:35 1s/step - accuracy: 0.7656 - loss: 0.8804
# Epoch 112: val_accuracy did not improve from 0.67406
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - accuracy: 0.7656 - loss: 0.8804 - val_accuracy: 0.6733 - val_loss: 1.0718 - learning_rate: 2.0000e-05
# Epoch 113/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7062 - loss: 0.9408
# Epoch 113: val_accuracy did not improve from 0.67406
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 422s 1s/step - accuracy: 0.7062 - loss: 0.9408 - val_accuracy: 0.6673 - val_loss: 1.0790 - learning_rate: 2.0000e-05
# Epoch 114/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 7:00 1s/step - accuracy: 0.7500 - loss: 0.8528
# Epoch 114: val_accuracy did not improve from 0.67406
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 30s 76ms/step - accuracy: 0.7500 - loss: 0.8528 - val_accuracy: 0.6675 - val_loss: 1.0794 - learning_rate: 2.0000e-05
# Epoch 115/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7063 - loss: 0.9322
# Epoch 115: val_accuracy did not improve from 0.67406
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 422s 1s/step - accuracy: 0.7063 - loss: 0.9323 - val_accuracy: 0.6730 - val_loss: 1.0770 - learning_rate: 2.0000e-05
# Epoch 116/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 6:31 1s/step - accuracy: 0.6406 - loss: 1.0907
# Epoch 116: val_accuracy did not improve from 0.67406
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - accuracy: 0.6406 - loss: 1.0907 - val_accuracy: 0.6733 - val_loss: 1.0778 - learning_rate: 2.0000e-05
# Epoch 117/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7158 - loss: 0.9289
# Epoch 117: val_accuracy improved from 0.67406 to 0.67656, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 422s 1s/step - accuracy: 0.7158 - loss: 0.9289 - val_accuracy: 0.6766 - val_loss: 1.0661 - learning_rate: 2.0000e-05
# Epoch 118/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 5:28 873ms/step - accuracy: 0.7188 - loss: 0.9053
# Epoch 118: val_accuracy improved from 0.67656 to 0.67672, saving model to model_output_v3\best_model_over_70.keras
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 30s 77ms/step - accuracy: 0.7188 - loss: 0.9053 - val_accuracy: 0.6767 - val_loss: 1.0662 - learning_rate: 2.0000e-05
# Epoch 119/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7012 - loss: 0.9422
# Epoch 119: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 420s 1s/step - accuracy: 0.7012 - loss: 0.9421 - val_accuracy: 0.6702 - val_loss: 1.0693 - learning_rate: 2.0000e-05
# Epoch 120/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 6:13 994ms/step - accuracy: 0.7969 - loss: 0.8232
# Epoch 120: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - accuracy: 0.7969 - loss: 0.8232 - val_accuracy: 0.6708 - val_loss: 1.0692 - learning_rate: 2.0000e-05
# Epoch 121/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7119 - loss: 0.9282
# Epoch 121: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 418s 1s/step - accuracy: 0.7119 - loss: 0.9282 - val_accuracy: 0.6736 - val_loss: 1.0736 - learning_rate: 2.0000e-05
# Epoch 122/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 6:39 1s/step - accuracy: 0.6875 - loss: 0.9192
# Epoch 122: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - accuracy: 0.6875 - loss: 0.9192 - val_accuracy: 0.6731 - val_loss: 1.0735 - learning_rate: 2.0000e-05
# Epoch 123/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7082 - loss: 0.9301
# Epoch 123: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 502s 1s/step - accuracy: 0.7082 - loss: 0.9301 - val_accuracy: 0.6708 - val_loss: 1.0703 - learning_rate: 2.0000e-05
# Epoch 124/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 11:46 2s/step - accuracy: 0.7344 - loss: 0.8091
# Epoch 124: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 55s 141ms/step - accuracy: 0.7344 - loss: 0.8091 - val_accuracy: 0.6705 - val_loss: 1.0707 - learning_rate: 2.0000e-05
# Epoch 125/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7105 - loss: 0.9247
# Epoch 125: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 763s 2s/step - accuracy: 0.7105 - loss: 0.9247 - val_accuracy: 0.6728 - val_loss: 1.0707 - learning_rate: 2.0000e-05
# Epoch 126/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 11:37 2s/step - accuracy: 0.6406 - loss: 1.0439
# Epoch 126: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 55s 141ms/step - accuracy: 0.6406 - loss: 1.0439 - val_accuracy: 0.6733 - val_loss: 1.0703 - learning_rate: 2.0000e-05
# Epoch 127/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7075 - loss: 0.9322
# Epoch 127: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 764s 2s/step - accuracy: 0.7075 - loss: 0.9322 - val_accuracy: 0.6752 - val_loss: 1.0734 - learning_rate: 2.0000e-05
# Epoch 128/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 11:47 2s/step - accuracy: 0.7969 - loss: 0.7336
# Epoch 128: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 55s 141ms/step - accuracy: 0.7969 - loss: 0.7336 - val_accuracy: 0.6745 - val_loss: 1.0741 - learning_rate: 2.0000e-05
# Epoch 129/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7090 - loss: 0.9225
# Epoch 129: val_accuracy did not improve from 0.67672
#
# Epoch 129: ReduceLROnPlateau reducing learning rate to 4.000000262749381e-06.
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 764s 2s/step - accuracy: 0.7090 - loss: 0.9225 - val_accuracy: 0.6764 - val_loss: 1.0706 - learning_rate: 2.0000e-05
# Epoch 130/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 11:47 2s/step - accuracy: 0.6719 - loss: 0.9404
# Epoch 130: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 53s 136ms/step - accuracy: 0.6719 - loss: 0.9404 - val_accuracy: 0.6764 - val_loss: 1.0708 - learning_rate: 4.0000e-06
# Epoch 131/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7097 - loss: 0.9264
# Epoch 131: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 611s 2s/step - accuracy: 0.7097 - loss: 0.9264 - val_accuracy: 0.6739 - val_loss: 1.0722 - learning_rate: 4.0000e-06
# Epoch 132/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 6:27 1s/step - accuracy: 0.6562 - loss: 1.0259
# Epoch 132: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.6562 - loss: 1.0259 - val_accuracy: 0.6737 - val_loss: 1.0721 - learning_rate: 4.0000e-06
# Epoch 133/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7127 - loss: 0.9269
# Epoch 133: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 427s 1s/step - accuracy: 0.7127 - loss: 0.9269 - val_accuracy: 0.6728 - val_loss: 1.0747 - learning_rate: 4.0000e-06
# Epoch 134/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 6:26 1s/step - accuracy: 0.7188 - loss: 0.8823
# Epoch 134: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - accuracy: 0.7188 - loss: 0.8823 - val_accuracy: 0.6727 - val_loss: 1.0746 - learning_rate: 4.0000e-06
# Epoch 135/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7168 - loss: 0.9088
# Epoch 135: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 448s 1s/step - accuracy: 0.7168 - loss: 0.9088 - val_accuracy: 0.6723 - val_loss: 1.0782 - learning_rate: 4.0000e-06
# Epoch 136/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 7:06 1s/step - accuracy: 0.7344 - loss: 1.0011
# Epoch 136: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 34s 87ms/step - accuracy: 0.7344 - loss: 1.0011 - val_accuracy: 0.6722 - val_loss: 1.0781 - learning_rate: 4.0000e-06
# Epoch 137/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7180 - loss: 0.9123
# Epoch 137: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 623s 2s/step - accuracy: 0.7180 - loss: 0.9123 - val_accuracy: 0.6736 - val_loss: 1.0717 - learning_rate: 4.0000e-06
# Epoch 138/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 14:48 2s/step - accuracy: 0.6562 - loss: 0.9603
# Epoch 138: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 54s 138ms/step - accuracy: 0.6562 - loss: 0.9603 - val_accuracy: 0.6734 - val_loss: 1.0719 - learning_rate: 4.0000e-06
# Epoch 139/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7116 - loss: 0.9234
# Epoch 139: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 1113s 3s/step - accuracy: 0.7116 - loss: 0.9234 - val_accuracy: 0.6716 - val_loss: 1.0750 - learning_rate: 4.0000e-06
# Epoch 140/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 14:44 2s/step - accuracy: 0.7812 - loss: 0.8837
# Epoch 140: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 66s 170ms/step - accuracy: 0.7812 - loss: 0.8837 - val_accuracy: 0.6716 - val_loss: 1.0748 - learning_rate: 4.0000e-06
# Epoch 141/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7153 - loss: 0.9248
# Epoch 141: val_accuracy did not improve from 0.67672
#
# Epoch 141: ReduceLROnPlateau reducing learning rate to 8.000000889296644e-07.
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 938s 2s/step - accuracy: 0.7152 - loss: 0.9248 - val_accuracy: 0.6742 - val_loss: 1.0730 - learning_rate: 4.0000e-06
# Epoch 142/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 18:12 3s/step - accuracy: 0.6719 - loss: 0.9375
# Epoch 142: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 58s 146ms/step - accuracy: 0.6719 - loss: 0.9375 - val_accuracy: 0.6744 - val_loss: 1.0731 - learning_rate: 8.0000e-07
# Epoch 143/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7147 - loss: 0.9099
# Epoch 143: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 988s 3s/step - accuracy: 0.7147 - loss: 0.9099 - val_accuracy: 0.6739 - val_loss: 1.0731 - learning_rate: 8.0000e-07
# Epoch 144/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 14:49 2s/step - accuracy: 0.6406 - loss: 1.0732
# Epoch 144: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 58s 149ms/step - accuracy: 0.6406 - loss: 1.0732 - val_accuracy: 0.6737 - val_loss: 1.0732 - learning_rate: 8.0000e-07
# Epoch 145/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7188 - loss: 0.9081
# Epoch 145: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 952s 3s/step - accuracy: 0.7188 - loss: 0.9080 - val_accuracy: 0.6733 - val_loss: 1.0724 - learning_rate: 8.0000e-07
# Epoch 146/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 21:12 3s/step - accuracy: 0.6875 - loss: 1.0426
# Epoch 146: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 77s 195ms/step - accuracy: 0.6875 - loss: 1.0426 - val_accuracy: 0.6736 - val_loss: 1.0723 - learning_rate: 8.0000e-07
# Epoch 147/200
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7171 - loss: 0.9195
# Epoch 147: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 1052s 3s/step - accuracy: 0.7171 - loss: 0.9194 - val_accuracy: 0.6730 - val_loss: 1.0737 - learning_rate: 8.0000e-07
# Epoch 148/200
#   1/377 ━━━━━━━━━━━━━━━━━━━━ 20:51 3s/step - accuracy: 0.7031 - loss: 0.9379
# Epoch 148: val_accuracy did not improve from 0.67672
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 134s 348ms/step - accuracy: 0.7031 - loss: 0.9379 - val_accuracy: 0.6731 - val_loss: 1.0738 - learning_rate: 8.0000e-07
# Epoch 148: early stopping
# Restoring model weights from the end of the best epoch: 118.

# %%
# --- 7. Evaluate the Model ---
print("\nEvaluating the best model on the validation set...")
# Load the best model using the .keras format
best_model = tf.keras.models.load_model(checkpoint_filepath)
val_loss, val_accuracy = best_model.evaluate(validation_generator)
print(f"Validation Loss (Best Model): {val_loss:.4f}")
print(f"Validation Accuracy (Best Model): {val_accuracy:.4f}")
# Out:
# Evaluating the best model on the validation set...
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 50s 463ms/step - accuracy: 0.6290 - loss: 1.2156
# Validation Loss (Best Model): 1.0609
# Validation Accuracy (Best Model): 0.6786

# %%
# --- 8. Visualize Results ---
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.grid(True)

plt.tight_layout()
plt.savefig(os.path.join(output_dir, 'training_history.png'))
plt.show()

# %%
# --- 9. Further steps: Confusion Matrix, Classification Report for detailed analysis ---
print("\nGenerating Classification Report and Confusion Matrix...")
validation_generator.reset() # Reset validation generator to ensure correct order
y_true_classes = validation_generator.classes[validation_generator.index_array]

# Predict on the entire validation set
predictions = best_model.predict(validation_generator)
y_pred_classes = np.argmax(predictions, axis=1)

class_labels = list(train_generator.class_indices.keys())
print("\nClassification Report:")
print(classification_report(y_true_classes, y_pred_classes, target_names=class_labels))

print("\nConfusion Matrix:")
cm = confusion_matrix(y_true_classes, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.savefig(os.path.join(output_dir, 'confusion_matrix.png'))
plt.show()
# Out:
# Generating Classification Report and Confusion Matrix...
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 51s 493ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.59      0.65      0.62       847
#      disgust       0.64      0.37      0.47       104
#         fear       0.60      0.28      0.38       894
#        happy       0.89      0.88      0.89      1662
#      neutral       0.56      0.75      0.64      1106
#          sad       0.56      0.56      0.56      1055
#     surprise       0.76      0.82      0.79       792
#
#     accuracy                           0.68      6460
#    macro avg       0.66      0.62      0.62      6460
# weighted avg       0.68      0.68      0.67      6460
#
#
# Confusion Matrix:

# %%
print(f"\nTraining completed. Best model saved to: {checkpoint_filepath}")
print(f"Training logs saved to: {os.path.join(output_dir, 'training_log.csv')}")
print(f"Training history plot saved to: {os.path.join(output_dir, 'training_history.png')}")
print(f"Confusion matrix plot saved to: {os.path.join(output_dir, 'confusion_matrix.png')}")
# Out:
# Training completed. Best model saved to: model_output_v3\best_model_over_70.keras
# Training logs saved to: model_output_v3\training_log.csv
# Training history plot saved to: model_output_v3\training_history.png
# Confusion matrix plot saved to: model_output_v3\confusion_matrix.png

# %%
# --- Save model as .h5 ---
h5_filepath = os.path.join(output_dir, 'best_model_over_70.h5')
best_model.save(h5_filepath)
print(f"Model also saved in HDF5 (.h5) format to: {h5_filepath}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model also saved in HDF5 (.h5) format to: model_output_v3\best_model_over_70.h5

# %%
import matplotlib.pyplot as plt

# Create a single figure with two subplots
plt.figure(figsize=(14, 6))  # Wider plot for better separation of subplots

# --- Accuracy Plot ---
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', marker='x')
plt.title('Accuracy vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# --- Loss Plot ---
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss', marker='o')
plt.plot(history.history['val_loss'], label='Validation Loss', marker='x')
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig(os.path.join(output_dir, 'accuracy_loss_comparison.png'))  # Save the figure
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf

# Define validation directory path (make sure this is correct for your system)
val_path = 'D:/Faces/validation'

# Initialize the validation ImageDataGenerator with rescaling only
val_aug = ImageDataGenerator(rescale=1./255)

# Create validation data generator
val_data = val_aug.flow_from_directory(
    val_path,
    target_size=(48, 48),
    color_mode='grayscale',
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# Load your trained model (adjust path if necessary)
model = tf.keras.models.load_model('model_output_v3/best_model_over_70.keras')

# Predict on validation data
val_predictions = model.predict(val_data)
val_true_labels = val_data.classes
class_names = list(val_data.class_indices.keys())
n_classes = len(class_names)

# Binarize true labels for ROC computation
y_true = label_binarize(val_true_labels, classes=np.arange(n_classes))

# Plot ROC curves for each class
plt.figure(figsize=(10, 8))
for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_true[:, i], val_predictions[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label=f'{class_names[i]} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Each Emotion Class')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.savefig('model_output_v3/roc_curve.png')  # Save plot
plt.show()
# Out:
# Found 6460 images belonging to 7 classes.
# C:\Users\Navindya\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 53s 256ms/step

# %%
import pandas as pd

# Load CSV and skip repeated headers by removing rows where 'val_accuracy' column equals 'val_accuracy' string
log_df = pd.read_csv('model_output_v3/training_log.csv')

# Filter out rows where 'val_accuracy' column contains the string 'val_accuracy' (the header)
log_df = log_df[log_df['val_accuracy'] != 'val_accuracy']

# Convert columns to numeric, coercing errors to NaN
log_df['accuracy'] = pd.to_numeric(log_df['accuracy'], errors='coerce')
log_df['val_accuracy'] = pd.to_numeric(log_df['val_accuracy'], errors='coerce')

# Drop rows with NaNs if any (optional, but recommended)
log_df = log_df.dropna(subset=['accuracy', 'val_accuracy'])

final_train_accuracy = float(log_df['accuracy'].iloc[-1])
final_val_accuracy = float(log_df['val_accuracy'].iloc[-1])
best_val_accuracy = float(log_df['val_accuracy'].max())

print(f"\nFinal Training Accuracy: {final_train_accuracy:.4f}")
print(f"Final Validation Accuracy: {final_val_accuracy:.4f}")
print(f"Best Validation Accuracy Achieved During Training: {best_val_accuracy:.4f}")
# Out:
# Final Training Accuracy: 0.7031
# Final Validation Accuracy: 0.6731
# Best Validation Accuracy Achieved During Training: 0.6767
